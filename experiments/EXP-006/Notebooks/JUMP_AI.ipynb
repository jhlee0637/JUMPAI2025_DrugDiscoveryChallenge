# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.2-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from xgboost) (1.13.1)
# Downloading xgboost-3.0.2-py3-none-macosx_12_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 15.9 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# 이미 설정하신 SEED 값 활용
SEED = 42

# 필수 라이브러리 import
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
import xgboost as xgb
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# 재현성 보장
np.random.seed(SEED)

# %%
def extract_molecular_features(smiles_list, verbose=True):
    """
    Morgan FP + 15개 RDKit descriptor 추출
    (FractionCSP3 철자 수정, 실패 시 0 반환)
    """
    features, failed = [], 0
    frac_csp3_fn = getattr(Descriptors, "FractionCSP3", None)

    for i, smi in enumerate(smiles_list):
        if verbose and i % 1000 == 0:
            print(f"처리 {i}/{len(smiles_list)}")

        mol = Chem.MolFromSmiles(smi)
        if mol is None:
            features.append(np.zeros(2048 + 15))
            failed += 1
            continue

        fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
        desc = [
            Descriptors.MolWt(mol),
            Descriptors.MolLogP(mol),
            Descriptors.NumHDonors(mol),
            Descriptors.NumHAcceptors(mol),
            Descriptors.TPSA(mol),
            Descriptors.NumRotatableBonds(mol),
            Descriptors.NumAromaticRings(mol),
            Descriptors.NumSaturatedRings(mol),
            Descriptors.NumAliphaticRings(mol),
            safe_call(frac_csp3_fn, mol) if frac_csp3_fn else 0.0,
            Descriptors.BertzCT(mol),
            Descriptors.BalabanJ(mol),
            Descriptors.HallKierAlpha(mol),
            Descriptors.HeavyAtomCount(mol),
            Descriptors.FpDensityMorgan2(mol),
        ]
        desc = [0 if pd.isna(x) else x for x in desc]
        features.append(np.concatenate([np.array(fp), np.array(desc)]))

    print(f"완료 – 실패 {failed}/{len(smiles_list)}")
    return np.array(features)

# %%
# 데이터 파일 로드
def load_and_preprocess_data():
    """
    학습 데이터와 테스트 데이터를 로드하고 전처리
    """
    # 학습 데이터 로드 (파일명은 실제 데이터에 맞게 수정)
    try:
        train_data = pd.read_csv('/Users/junu/Documents/Project/Jump_Team_Project/Data/ChEMBL_ASK1(IC50).csv', sep=';')
        print(f"학습 데이터 로드 완료: {train_data.shape}")
    except:
        print("ChEMBL_ASK1(IC50).csv 파일을 찾을 수 없습니다.")
        return None, None, None, None
    
    # 추가 데이터가 있다면 병합
    try:
        pubchem_data = pd.read_csv('/Users/junu/Documents/Project/Jump_Team_Project/Data/Pubchem_ASK1.csv')
        train_data = pd.concat([train_data, pubchem_data], ignore_index=True)
        print(f"PubChem 데이터 병합 완료: {train_data.shape}")
    except:
        print("PubChem 데이터 없음, 기본 데이터만 사용")
    
    # 테스트 데이터 로드
    try:
        test_data = pd.read_csv('/Users/junu/Documents/Project/Jump_Team_Project/Data/test.csv')
        print(f"테스트 데이터 로드 완료: {test_data.shape}")
    except:
        print("test.csv 파일을 찾을 수 없습니다.")
        return None, None, None, None
    
    # 데이터 정리
    train_data = train_data.dropna(subset=['Smiles'])
    test_data = test_data.dropna(subset=['Smiles'])
    
    # IC50 값 처리 (컬럼명이 다를 수 있으니 확인)
    if 'IC50_nM' in train_data.columns:
        ic50_col = 'IC50_nM'
    elif 'Value' in train_data.columns:
        ic50_col = 'Value'
    else:
        ic50_col = train_data.columns[-1]  # 마지막 컬럼 사용
    
    # 이상치 제거 (IC50 값)
    Q1 = train_data[ic50_col].quantile(0.25)
    Q3 = train_data[ic50_col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    train_data = train_data[(train_data[ic50_col] >= lower_bound) & 
                           (train_data[ic50_col] <= upper_bound)]
    
    print(f"이상치 제거 후 학습 데이터: {train_data.shape}")
    
    return train_data, test_data, ic50_col, train_data['Smiles'].tolist(), test_data['Smiles'].tolist()

# 데이터 로드 실행
train_data, test_data, ic50_col, train_smiles, test_smiles = load_and_preprocess_data()
# Out:
# 학습 데이터 로드 완료: (824, 48)
# PubChem 데이터 병합 완료: (24619, 81)
# 테스트 데이터 로드 완료: (127, 2)
# 이상치 제거 후 학습 데이터: (657, 81)

# %%
if train_data is not None:
    # 분자 특성 추출
    print("학습 데이터 특성 추출 중...")
    X_train = extract_molecular_features(train_smiles)
    
    print("테스트 데이터 특성 추출 중...")
    X_test = extract_molecular_features(test_smiles)
    
    # 타겟 변수 처리 (log 변환으로 분포 안정화)
    y_train = np.log1p(train_data[ic50_col].values)
    
    # 특성 스케일링
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    print(f"특성 추출 완료:")
    print(f"- 학습 특성: {X_train.shape}")
    print(f"- 테스트 특성: {X_test.shape}")
    print(f"- 타겟 분포: 평균={y_train.mean():.3f}, 표준편차={y_train.std():.3f}")
# Out:
# 학습 데이터 특성 추출 중...
# 처리 0/657
# [15:45:16] DEPRECATION WARNING: please use MorganGenerator
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 if train_data is not None:
#       2     # 분자 특성 추출
#       3     print("학습 데이터 특성 추출 중...")
# ----> 4     X_train = extract_molecular_features(train_smiles)
#       6     print("테스트 데이터 특성 추출 중...")
#       7     X_test = extract_molecular_features(test_smiles)
#
# Cell In[18], line 30, in extract_molecular_features(smiles_list, verbose)
#      17     continue
#      19 fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
#      20 desc = [
#      21     Descriptors.MolWt(mol),
#      22     Descriptors.MolLogP(mol),
#      23     Descriptors.NumHDonors(mol),
#      24     Descriptors.NumHAcceptors(mol),
#      25     Descriptors.TPSA(mol),
#      26     Descriptors.NumRotatableBonds(mol),
#      27     Descriptors.NumAromaticRings(mol),
#      28     Descriptors.NumSaturatedRings(mol),
#      29     Descriptors.NumAliphaticRings(mol),
# ---> 30     safe_call(frac_csp3_fn, mol) if frac_csp3_fn else 0.0,
#      31     Descriptors.BertzCT(mol),
#      32     Descriptors.BalabanJ(mol),
#      33     Descriptors.HallKierAlpha(mol),
#      34     Descriptors.HeavyAtomCount(mol),
#      35     Descriptors.FpDensityMorgan2(mol),
#      36 ]
#      37 desc = [0 if pd.isna(x) else x for x in desc]
#      38 features.append(np.concatenate([np.array(fp), np.array(desc)]))
#
# NameError: name 'safe_call' is not defined

# %%
import lightgbm as lgb
print(lgb.__version__)
# Out:
# 4.6.0

# %%
pip install --upgrade lightgbm
# Out:
# Requirement already satisfied: lightgbm in /opt/anaconda3/lib/python3.12/site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /opt/anaconda3/lib/python3.12/site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from lightgbm) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp312-cp312-macosx_11_0_universal2.whl.metadata (1.4 kB)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (from catboost) (3.9.2)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /opt/anaconda3/lib/python3.12/site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /opt/anaconda3/lib/python3.12/site-packages (from catboost) (2.2.3)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.12/site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.12/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from plotly->catboost) (8.2.3)
# Downloading catboost-1.2.8-cp312-cp312-macosx_11_0_universal2.whl (27.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 18.6 MB/s eta 0:00:00a 0:00:01
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Installing collected packages: graphviz, catboost
# Successfully installed catboost-1.2.8 graphviz-0.21
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (1.13.3)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (2.0.34)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /opt/anaconda3/lib/python3.12/site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /opt/anaconda3/lib/python3.12/site-packages (from alembic>=1.5.0->optuna) (1.2.3)
# Requirement already satisfied: typing-extensions>=4 in /opt/anaconda3/lib/python3.12/site-packages (from alembic>=1.5.0->optuna) (4.13.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/anaconda3/lib/python3.12/site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.9.0 optuna-4.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mordred
# Out:
# Collecting mordred
#   Downloading mordred-1.2.0.tar.gz (128 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six==1.* in /opt/anaconda3/lib/python3.12/site-packages (from mordred) (1.16.0)
# Requirement already satisfied: numpy==1.* in /opt/anaconda3/lib/python3.12/site-packages (from mordred) (1.26.4)
# Collecting networkx==2.* (from mordred)
#   Downloading networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.6 MB/s eta 0:00:00
# Building wheels for collected packages: mordred
#   Building wheel for mordred (setup.py) ... done
#   Created wheel for mordred: filename=mordred-1.2.0-py3-none-any.whl size=176718 sha256=4e5dde1fe30b97de1e1cd1447f91e7df9019b0489289241dd0188e39cfd7071e
#   Stored in directory: /Users/junu/Library/Caches/pip/wheels/e8/79/b8/f4f1dfbb736c2b8605cf5068cd633f4d2869defb89908aef93
# Successfully built mordred
# Installing collected packages: networkx, mordred
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.3
#     Uninstalling networkx-3.3:
#       Successfully uninstalled networkx-3.3
# Successfully installed mordred-1.2.0 networkx-2.8.8
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge lightgbm xgboost catboost
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - catboost
#     - lightgbm
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     atk-1.0-2.38.0             |       hcb7b3dd_1         364 KB  conda-forge
#     boost-cpp-1.84.0           |       hca5e981_3          16 KB  conda-forge
#     ca-certificates-2025.7.9   |       hbd8a1cb_0         149 KB  conda-forge
#     cairo-1.18.0               |       hd1e100b_0         877 KB  conda-forge
#     catboost-1.2.7             |cpu_py312hc95783c_1         8.5 MB  conda-forge
#     certifi-2025.7.9           |     pyhd8ed1ab_0         153 KB  conda-forge
#     conda-24.11.3              |  py312h81bd7bf_0         1.1 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       h82840c6_0         232 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fribidi-1.0.10             |       h27ca646_0          59 KB  conda-forge
#     gdk-pixbuf-2.42.10         |       h9bcf4fe_0         522 KB  conda-forge
#     graphite2-1.3.14           |       h286801f_0          80 KB  conda-forge
#     graphviz-8.0.3             |       h4f8fbd6_0         4.4 MB  conda-forge
#     gtk2-2.24.33               |       h57013de_2         7.0 MB  conda-forge
#     gts-0.7.6                  |       he42f4ea_4         297 KB  conda-forge
#     harfbuzz-8.3.0             |       h8f0ba13_0         1.2 MB  conda-forge
#     icu-73.2                   |       hc8870d7_0        11.4 MB  conda-forge
#     khronos-opencl-icd-loader-2024.10.24|       h5505292_1          34 KB  conda-forge
#     libboost-1.84.0            |       h17eb2be_3         1.9 MB  conda-forge
#     libboost-devel-1.84.0      |       hf450f58_3          39 KB  conda-forge
#     libboost-headers-1.84.0    |       hce30654_3        13.2 MB  conda-forge
#     libcxx-20.1.8              |       ha82da77_0         554 KB  conda-forge
#     libexpat-2.6.3             |       hf9b8971_0          62 KB  conda-forge
#     libgd-2.3.3                |       h14f8a72_1         200 KB
#     liblightgbm-4.6.0          |   cpu_h0bc706f_0         1.3 MB  conda-forge
#     libltdl-2.4.3a             |       h286801f_0          36 KB  conda-forge
#     librsvg-2.54.4             |       ha2634a2_0         7.0 MB  conda-forge
#     libsqlite-3.46.0           |       hfb93653_0         811 KB  conda-forge
#     libtool-2.5.4              |       h286801f_0         405 KB  conda-forge
#     libxgboost-3.0.2           |   cpu_hf17a1b1_0         1.4 MB  conda-forge
#     libzlib-1.2.13             |       hfb2fe0b_6          46 KB  conda-forge
#     lightgbm-4.6.0             |         cpu_py_0          84 KB  conda-forge
#     llvm-openmp-20.1.7         |       hdb05f8b_0         275 KB  conda-forge
#     opencl-headers-2025.06.13  |       h286801f_0          54 KB  conda-forge
#     pango-1.50.14              |       hcf40dda_2         416 KB  conda-forge
#     pixman-0.46.2              |       h2f9eb0b_0         210 KB  conda-forge
#     py-xgboost-3.0.2           | cpu_pyhc5f55e3_0         145 KB  conda-forge
#     python-3.12.2              |hdf0ec26_0_cpython        12.5 MB  conda-forge
#     python-graphviz-0.21       |     pyhbacfb6d_0          38 KB  conda-forge
#     python_abi-3.12            |          7_cp312           7 KB  conda-forge
#     xgboost-3.0.2              | cpu_pyhc1a9e11_0          16 KB  conda-forge
#     zlib-1.2.13                |       hfb2fe0b_6          76 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        79.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   atk-1.0            conda-forge/osx-arm64::atk-1.0-2.38.0-hcb7b3dd_1
#   cairo              conda-forge/osx-arm64::cairo-1.18.0-hd1e100b_0
#   catboost           conda-forge/osx-arm64::catboost-1.2.7-cpu_py312hc95783c_1
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/osx-arm64::fontconfig-2.14.2-h82840c6_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fribidi            conda-forge/osx-arm64::fribidi-1.0.10-h27ca646_0
#   gdk-pixbuf         conda-forge/osx-arm64::gdk-pixbuf-2.42.10-h9bcf4fe_0
#   graphite2          conda-forge/osx-arm64::graphite2-1.3.14-h286801f_0
#   graphviz           conda-forge/osx-arm64::graphviz-8.0.3-h4f8fbd6_0
#   gtk2               conda-forge/osx-arm64::gtk2-2.24.33-h57013de_2
#   gts                conda-forge/osx-arm64::gts-0.7.6-he42f4ea_4
#   harfbuzz           conda-forge/osx-arm64::harfbuzz-8.3.0-h8f0ba13_0
#   khronos-opencl-ic~ conda-forge/osx-arm64::khronos-opencl-icd-loader-2024.10.24-h5505292_1
#   libboost-devel     conda-forge/osx-arm64::libboost-devel-1.84.0-hf450f58_3
#   libboost-headers   conda-forge/osx-arm64::libboost-headers-1.84.0-hce30654_3
#   libexpat           conda-forge/osx-arm64::libexpat-2.6.3-hf9b8971_0
#   libgd              pkgs/main/osx-arm64::libgd-2.3.3-h14f8a72_1
#   liblightgbm        conda-forge/osx-arm64::liblightgbm-4.6.0-cpu_h0bc706f_0
#   libltdl            conda-forge/osx-arm64::libltdl-2.4.3a-h286801f_0
#   librsvg            conda-forge/osx-arm64::librsvg-2.54.4-ha2634a2_0
#   libsqlite          conda-forge/osx-arm64::libsqlite-3.46.0-hfb93653_0
#   libtool            conda-forge/osx-arm64::libtool-2.5.4-h286801f_0
#   libxgboost         conda-forge/osx-arm64::libxgboost-3.0.2-cpu_hf17a1b1_0
#   libzlib            conda-forge/osx-arm64::libzlib-1.2.13-hfb2fe0b_6
#   lightgbm           conda-forge/noarch::lightgbm-4.6.0-cpu_py_0
#   opencl-headers     conda-forge/osx-arm64::opencl-headers-2025.06.13-h286801f_0
#   pango              conda-forge/osx-arm64::pango-1.50.14-hcf40dda_2
#   pixman             conda-forge/osx-arm64::pixman-0.46.2-h2f9eb0b_0
#   py-xgboost         conda-forge/noarch::py-xgboost-3.0.2-cpu_pyhc5f55e3_0
#   python-graphviz    conda-forge/noarch::python-graphviz-0.21-pyhbacfb6d_0
#   python_abi         conda-forge/noarch::python_abi-3.12-7_cp312
#   xgboost            conda-forge/noarch::xgboost-3.0.2-cpu_pyhc1a9e11_0
#
# The following packages will be UPDATED:
#
#   boost-cpp          pkgs/main::boost-cpp-1.82.0-h48ca7d4_2 --> conda-forge::boost-cpp-1.84.0-hca5e981_3
#   ca-certificates    pkgs/main/osx-arm64::ca-certificates-~ --> conda-forge/noarch::ca-certificates-2025.7.9-hbd8a1cb_0
#   certifi            pkgs/main/osx-arm64::certifi-2025.1.3~ --> conda-forge/noarch::certifi-2025.7.9-pyhd8ed1ab_0
#   icu                        pkgs/main::icu-73.1-h313beb8_0 --> conda-forge::icu-73.2-hc8870d7_0
#   libboost            pkgs/main::libboost-1.82.0-h0bc93f9_2 --> conda-forge::libboost-1.84.0-h17eb2be_3
#   libcxx                pkgs/main::libcxx-14.0.6-h848a8c0_0 --> conda-forge::libcxx-20.1.8-ha82da77_0
#   llvm-openmp        pkgs/main::llvm-openmp-14.0.6-hc6e570~ --> conda-forge::llvm-openmp-20.1.7-hdb05f8b_0
#   openssl              pkgs/main::openssl-3.0.16-h02f6b3c_0 --> conda-forge::openssl-3.5.1-h81ee809_0
#   zlib                    pkgs/main::zlib-1.2.13-h18a0788_1 --> conda-forge::zlib-1.2.13-hfb2fe0b_6
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              pkgs/main::conda-24.11.3-py312hca03da~ --> conda-forge::conda-24.11.3-py312h81bd7bf_0
#   python                pkgs/main::python-3.12.7-h99e199e_0 --> conda-forge::python-3.12.2-hdf0ec26_0_cpython
#
#
#
# Downloading and Extracting Packages:
# libboost-headers-1.8 | 13.2 MB   |                                       |   0%
# python-3.12.2        | 12.5 MB   |                                       |   0%
#
# icu-73.2             | 11.4 MB   |                                       |   0%
#
#
# catboost-1.2.7       | 8.5 MB    |                                       |   0%
#
#
#
# gtk2-2.24.33         | 7.0 MB    |                                       |   0%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    |                                       |   0%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    |                                       |   0%
#
#
#
#
#
#
# libboost-1.84.0      | 1.9 MB    |                                       |   0%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# libxgboost-3.0.2     | 1.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 877 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-20.1.8        | 554 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 522 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 416 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.5.4        | 405 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# atk-1.0-2.38.0       | 364 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 297 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# icu-73.2             | 11.4 MB   |                                       |   0%
#
#
#
# gtk2-2.24.33         | 7.0 MB    | 6                                     |   2%
# python-3.12.2        | 12.5 MB   |                                       |   0%
#
# icu-73.2             | 11.4 MB   | ###8                                  |  10%
#
#
#
# gtk2-2.24.33         | 7.0 MB    | #######4                              |  20%
# python-3.12.2        | 12.5 MB   | #                                     |   3%
#
#
# catboost-1.2.7       | 8.5 MB    |                                       |   0%
#
# icu-73.2             | 11.4 MB   | ######9                               |  19%
#
#
#
# gtk2-2.24.33         | 7.0 MB    | #############1                        |  36%
# python-3.12.2        | 12.5 MB   | ##3                                   |   6%
#
#
# catboost-1.2.7       | 8.5 MB    | #                                     |   3%
#
# icu-73.2             | 11.4 MB   | #########6                            |  26%
#
#
#
# libboost-headers-1.8 | 13.2 MB   |                                       |   0%
# python-3.12.2        | 12.5 MB   | ####                                  |  11%
#
#
# libboost-headers-1.8 | 13.2 MB   | 3                                     |   1%
#
# icu-73.2             | 11.4 MB   | ############1                         |  33%
#
#
#
# gtk2-2.24.33         | 7.0 MB    | #######################               |  62%
# python-3.12.2        | 12.5 MB   | #####2                                |  14%
#
#
# libboost-headers-1.8 | 13.2 MB   | #1                                    |   3%
#
#
#
# gtk2-2.24.33         | 7.0 MB    | ###########################           |  73%
#
# icu-73.2             | 11.4 MB   | ##############2                       |  39%
#
#
# libboost-headers-1.8 | 13.2 MB   | ##5                                   |   7%
# python-3.12.2        | 12.5 MB   | ######3                               |  17%
#
#
#
# gtk2-2.24.33         | 7.0 MB    | ##############################9       |  84%
#
# libboost-headers-1.8 | 13.2 MB   | ####9                                 |  13%
# python-3.12.2        | 12.5 MB   | #######2                              |  20%
#
#
# catboost-1.2.7       | 8.5 MB    | ##########6                           |  29%
#
#
#
# gtk2-2.24.33         | 7.0 MB    | ##################################8   |  94%
#
# icu-73.2             | 11.4 MB   | ##################3                   |  50%
#
#
# libboost-headers-1.8 | 13.2 MB   | ######9                               |  19%
# python-3.12.2        | 12.5 MB   | ########1                             |  22%
#
#
#
# libboost-headers-1.8 | 13.2 MB   | #########2                            |  25%
#
#
# catboost-1.2.7       | 8.5 MB    | ##############8                       |  40%
#
# icu-73.2             | 11.4 MB   | ####################2                 |  55%
# libboost-headers-1.8 | 13.2 MB   | ############                          |  33%
#
#
# catboost-1.2.7       | 8.5 MB    | #################9                    |  49%
#
# icu-73.2             | 11.4 MB   | ######################                |  60%
# python-3.12.2        | 12.5 MB   | ##########7                           |  29%
#
#
#
#
# libboost-headers-1.8 | 13.2 MB   | ##############5                       |  39%
#
#
# catboost-1.2.7       | 8.5 MB    | ####################4                 |  55%
# python-3.12.2        | 12.5 MB   | ###########8                          |  32%
#
# icu-73.2             | 11.4 MB   | #######################6              |  64%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ##8                                   |   8%
#
#
# libboost-headers-1.8 | 13.2 MB   | ################7                     |  45%
# python-3.12.2        | 12.5 MB   | ############9                         |  35%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | #####6                                |  15%
#
# icu-73.2             | 11.4 MB   | #########################1            |  68%
#
#
# libboost-headers-1.8 | 13.2 MB   | ##################8                   |  51%
# python-3.12.2        | 12.5 MB   | #############9                        |  38%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ########8                             |  24%
#
# icu-73.2             | 11.4 MB   | ##########################4           |  72%
#
#
# libboost-headers-1.8 | 13.2 MB   | #####################                 |  57%
# python-3.12.2        | 12.5 MB   | ###############                       |  41%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ############1                         |  33%
#
# icu-73.2             | 11.4 MB   | ###########################7          |  75%
#
#
# libboost-headers-1.8 | 13.2 MB   | #######################4              |  63%
#
#
#
# gtk2-2.24.33         | 7.0 MB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | ################                      |  43%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ##############9                       |  40%
#
# libboost-headers-1.8 | 13.2 MB   | #########################8            |  70%
#
#
# catboost-1.2.7       | 8.5 MB    | ###############################3      |  85%
# python-3.12.2        | 12.5 MB   | #################                     |  46%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ##################1                   |  49%
#
# libboost-headers-1.8 | 13.2 MB   | ###########################9          |  76%
#
#
# catboost-1.2.7       | 8.5 MB    | #################################3    |  90%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ####################9                 |  57%
# python-3.12.2        | 12.5 MB   | ##################                    |  49%
#
# libboost-headers-1.8 | 13.2 MB   | ##############################3       |  82%
#
#
# catboost-1.2.7       | 8.5 MB    | ###################################2  |  95%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | #######################9              |  65%
# python-3.12.2        | 12.5 MB   | ###################                   |  52%
#
# libboost-headers-1.8 | 13.2 MB   | ################################7     |  89%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ###########################3          |  74%
#
#
# catboost-1.2.7       | 8.5 MB    | ##################################### | 100%
#
#
# catboost-1.2.7       | 8.5 MB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | ####################                  |  54%
#
# libboost-headers-1.8 | 13.2 MB   | ###################################5  |  96%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    | 1                                     |   0%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ##############################8       |  83%
# python-3.12.2        | 12.5 MB   | #####################2                |  57%
#
#
# catboost-1.2.7       | 8.5 MB    | ##################################### | 100%
#
# libboost-headers-1.8 | 13.2 MB   | ##################################### | 100%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    | ###5                                  |  10%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | #################################9    |  92%
# python-3.12.2        | 12.5 MB   | ######################2               |  60%
#
#
#
#
#
#
# libboost-1.84.0      | 1.9 MB    | 3                                     |   1%
#
# icu-73.2             | 11.4 MB   | ####################################7 |  99%
#
# icu-73.2             | 11.4 MB   | ##################################### | 100%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ##################################### | 100%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    | #######                               |  19%
# python-3.12.2        | 12.5 MB   | #######################5              |  64%
#
#
#
#
#
#
# libboost-1.84.0      | 1.9 MB    | ########################3             |  66%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
# libxgboost-3.0.2     | 1.4 MB    | 4                                     |   1%
#
#
#
#
#
#
# libboost-1.84.0      | 1.9 MB    | ##################################### | 100%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    | ###########5                          |  31%
# python-3.12.2        | 12.5 MB   | ########################6             |  67%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###########2                          |  30%
#
#
#
#
#
#
#
#
# libxgboost-3.0.2     | 1.4 MB    | ####################5                 |  55%
#
# icu-73.2             | 11.4 MB   | ##################################### | 100%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    | #################6                    |  48%
#
#
#
#
#
#
#
#
# libxgboost-3.0.2     | 1.4 MB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | ##########################1           |  71%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########################3             |  66%
#
#
#
#
#
#
# libboost-1.84.0      | 1.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
# libxgboost-3.0.2     | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libxgboost-3.0.2     | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    | ######################7               |  62%
# python-3.12.2        | 12.5 MB   | ###########################2          |  74%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | ###############4                      |  42%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | 5                                     |   1%
# python-3.12.2        | 12.5 MB   | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# liblightgbm-4.6.0    | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | 7                                     |   2%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 877 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
# harfbuzz-8.3.0       | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ####################1                 |  54%
# python-3.12.2        | 12.5 MB   | #############################9        |  81%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ##################################### | 100%
#
#
#
#
# librsvg-2.54.4       | 7.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | #################################5    |  91%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 877 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 877 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsqlite-3.46.0     | 811 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-20.1.8        | 554 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.0         | 877 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 522 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 416 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-20.1.8        | 554 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 522 KB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | ################################7     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 416 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ##################################### | 100%
#
#
#
#
#
# graphviz-8.0.3       | 4.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-20.1.8        | 554 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcxx-20.1.8        | 554 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 297 KB    | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | #5                                    |   4%
# python-3.12.2        | 12.5 MB   | #################################9    |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 297 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# atk-1.0-2.38.0       | 364 KB    | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# conda-24.11.3        | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 522 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 522 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 416 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 416 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# atk-1.0-2.38.0       | 364 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 297 KB    | ##################################### | 100%
# python-3.12.2        | 12.5 MB   | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gts-0.7.6            | 297 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.5.4        | 405 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# python-3.12.2        | 12.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.5.4        | 405 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# atk-1.0-2.38.0       | 364 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# atk-1.0-2.38.0       | 364 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.5.4        | 405 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtool-2.5.4        | 405 KB    | ##################################### | 100%
# libboost-headers-1.8 | 13.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: -
# \
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install optuna shap rdkit-pypi mordred-community
# Out:
# Requirement already satisfied: optuna in /opt/anaconda3/lib/python3.12/site-packages (4.4.0)
# Requirement already satisfied: shap in /opt/anaconda3/lib/python3.12/site-packages (0.47.2)
# ERROR: Could not find a version that satisfies the requirement rdkit-pypi (from versions: none)
# ERROR: No matching distribution found for rdkit-pypi
# Note: you may need to restart the kernel to use updated packages.
